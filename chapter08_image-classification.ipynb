# %% [markdown]
# This is a companion notebook for the book [Deep Learning with Python, Third Edition](https://www.manning.com/books/deep-learning-with-python-third-edition). For readability, it only contains runnable code blocks and section titles, and omits everything else in the book: text paragraphs, figures, and pseudocode.
#
# **If you want to be able to follow what's going on, I recommend reading the notebook side by side with your copy of the book.**
#
# The book's contents are available online at [deeplearningwithpython.io](https://deeplearningwithpython.io).

# %%
# !pip install keras keras-hub --upgrade -q
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 39.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 61.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 230.0/230.0 kB 16.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 56.2 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# keras-nlp 0.26.0 requires keras-hub==0.26.0, but you have keras-hub 0.31.1 which is incompatible.

# %%
import os
os.environ["KERAS_BACKEND"] = "jax"

# %%
# @title
import os
from IPython.core.magic import register_cell_magic

@register_cell_magic
def backend(line, cell):
    current, required = os.environ.get("KERAS_BACKEND", ""), line.split()[-1]
    if current == required:
        get_ipython().run_cell(cell)
    else:
        print(
            f"This cell requires the {required} backend. To run it, change KERAS_BACKEND to "
            f"\"{required}\" at the top of the notebook, restart the runtime, and rerun the notebook."
        )

# %% [markdown]
# ## Image classification

# %% [markdown]
# ### Introduction to ConvNets

# %%
import keras
from keras import layers

inputs = keras.Input(shape=(28, 28, 1))
x = layers.Conv2D(filters=64, kernel_size=3, activation="relu")(inputs)
x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Conv2D(filters=128, kernel_size=3, activation="relu")(x)
x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Conv2D(filters=256, kernel_size=3, activation="relu")(x)
x = layers.GlobalAveragePooling2D()(x)
outputs = layers.Dense(10, activation="softmax")(x)
model = keras.Model(inputs=inputs, outputs=outputs)

# %%
model.summary(line_length=80)
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                      ┃ Output Shape             ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)          │ (None, 28, 28, 1)        │             0 │
# ├───────────────────────────────────┼──────────────────────────┼───────────────┤
# │ conv2d (Conv2D)                   │ (None, 26, 26, 64)       │           640 │
# ├───────────────────────────────────┼──────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)      │ (None, 13, 13, 64)       │             0 │
# ├───────────────────────────────────┼──────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)                 │ (None, 11, 11, 128)      │        73,856 │
# ├───────────────────────────────────┼──────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)    │ (None, 5, 5, 128)        │             0 │
# ├───────────────────────────────────┼──────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)                 │ (None, 3, 3, 256)        │       295,168 │
# ├───────────────────────────────────┼──────────────────────────┼───────────────┤
# │ global_average_pooling2d          │ (None, 256)              │             0 │
# │ (GlobalAveragePooling2D)          │                          │               │
# ├───────────────────────────────────┼──────────────────────────┼───────────────┤
# │ dense (Dense)                     │ (None, 10)               │         2,570 │
# └───────────────────────────────────┴──────────────────────────┴───────────────┘
#  Total params: 372,234 (1.42 MB)
#  Trainable params: 372,234 (1.42 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
from keras.datasets import mnist

(train_images, train_labels), (test_images, test_labels) = mnist.load_data()
train_images = train_images.reshape((60000, 28, 28, 1))
train_images = train_images.astype("float32") / 255
test_images = test_images.reshape((10000, 28, 28, 1))
test_images = test_images.astype("float32") / 255
model.compile(
    optimizer="adam",
    loss="sparse_categorical_crossentropy",
    metrics=["accuracy"],
)
model.fit(train_images, train_labels, epochs=5, batch_size=64)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Epoch 1/5
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 27s 17ms/step - accuracy: 0.9220 - loss: 0.2496
# Epoch 2/5
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.9789 - loss: 0.0691
# Epoch 3/5
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9855 - loss: 0.0469
# Epoch 4/5
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9889 - loss: 0.0351
# Epoch 5/5
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9913 - loss: 0.0281

# %%
test_loss, test_acc = model.evaluate(test_images, test_labels)
print(f"Test accuracy: {test_acc:.3f}")
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - accuracy: 0.9912 - loss: 0.0258
# Test accuracy: 0.991

# %% [markdown]
# #### The convolution operation

# %% [markdown]
# ##### Understanding border effects and padding

# %% [markdown]
# ##### Understanding convolution strides

# %% [markdown]
# #### The max-pooling operation

# %%
inputs = keras.Input(shape=(28, 28, 1))
x = layers.Conv2D(filters=64, kernel_size=3, activation="relu")(inputs)
x = layers.Conv2D(filters=128, kernel_size=3, activation="relu")(x)
x = layers.Conv2D(filters=256, kernel_size=3, activation="relu")(x)
x = layers.GlobalAveragePooling2D()(x)
outputs = layers.Dense(10, activation="softmax")(x)
model_no_max_pool = keras.Model(inputs=inputs, outputs=outputs)

# %%
model_no_max_pool.summary(line_length=80)
# Out:
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                      ┃ Output Shape             ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_1 (InputLayer)        │ (None, 28, 28, 1)        │             0 │
# ├───────────────────────────────────┼──────────────────────────┼───────────────┤
# │ conv2d_3 (Conv2D)                 │ (None, 26, 26, 64)       │           640 │
# ├───────────────────────────────────┼──────────────────────────┼───────────────┤
# │ conv2d_4 (Conv2D)                 │ (None, 24, 24, 128)      │        73,856 │
# ├───────────────────────────────────┼──────────────────────────┼───────────────┤
# │ conv2d_5 (Conv2D)                 │ (None, 22, 22, 256)      │       295,168 │
# ├───────────────────────────────────┼──────────────────────────┼───────────────┤
# │ global_average_pooling2d_1        │ (None, 256)              │             0 │
# │ (GlobalAveragePooling2D)          │                          │               │
# ├───────────────────────────────────┼──────────────────────────┼───────────────┤
# │ dense_1 (Dense)                   │ (None, 10)               │         2,570 │
# └───────────────────────────────────┴──────────────────────────┴───────────────┘
#  Total params: 372,234 (1.42 MB)
#  Trainable params: 372,234 (1.42 MB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ### Training a ConvNet from scratch on a small dataset

# %% [markdown]
# #### The relevance of deep learning for small-data problems

# %% [markdown]
# #### Downloading the data

# %%
import kagglehub

kagglehub.login()
# Out:
# VBox(children=(HTML(value='<center> <img\nsrc=https://www.kaggle.com/static/images/site-logo.png\nalt=\'Kaggle…
# Kaggle credentials set.
# Kaggle credentials successfully validated.

# %%
download_path = kagglehub.competition_download("dogs-vs-cats")
# Out:
# Downloading to /root/.cache/kagglehub/competitions/dogs-vs-cats.archive...
# 100%|██████████| 812M/812M [00:07<00:00, 115MB/s]
# Extracting files...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import zipfile

with zipfile.ZipFile(download_path + "/train.zip", "r") as zip_ref:
    zip_ref.extractall(".")

# %%
import os, shutil, pathlib

original_dir = pathlib.Path("train")
new_base_dir = pathlib.Path("dogs_vs_cats_small")

def make_subset(subset_name, start_index, end_index):
    for category in ("cat", "dog"):
        dir = new_base_dir / subset_name / category
        os.makedirs(dir)
        fnames = [f"{category}.{i}.jpg" for i in range(start_index, end_index)]
        for fname in fnames:
            shutil.copyfile(src=original_dir / fname, dst=dir / fname)

make_subset("train", start_index=0, end_index=1000)
make_subset("validation", start_index=1000, end_index=1500)
make_subset("test", start_index=1500, end_index=2500)

# %% [markdown]
# #### Building your model

# %%
import keras
from keras import layers

inputs = keras.Input(shape=(180, 180, 3))
x = layers.Rescaling(1.0 / 255)(inputs)
x = layers.Conv2D(filters=32, kernel_size=3, activation="relu")(x)
x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Conv2D(filters=64, kernel_size=3, activation="relu")(x)
x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Conv2D(filters=128, kernel_size=3, activation="relu")(x)
x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Conv2D(filters=256, kernel_size=3, activation="relu")(x)
x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Conv2D(filters=512, kernel_size=3, activation="relu")(x)
x = layers.GlobalAveragePooling2D()(x)
outputs = layers.Dense(1, activation="sigmoid")(x)
model = keras.Model(inputs=inputs, outputs=outputs)

# %%
model.summary(line_length=80)
# Out:
# Model: "functional_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                      ┃ Output Shape             ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_2 (InputLayer)        │ (None, 180, 180, 3)      │             0 │
# ├───────────────────────────────────┼──────────────────────────┼───────────────┤
# │ rescaling (Rescaling)             │ (None, 180, 180, 3)      │             0 │
# ├───────────────────────────────────┼──────────────────────────┼───────────────┤
# │ conv2d_6 (Conv2D)                 │ (None, 178, 178, 32)     │           896 │
# ├───────────────────────────────────┼──────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)    │ (None, 89, 89, 32)       │             0 │
# ├───────────────────────────────────┼──────────────────────────┼───────────────┤
# │ conv2d_7 (Conv2D)                 │ (None, 87, 87, 64)       │        18,496 │
# ├───────────────────────────────────┼──────────────────────────┼───────────────┤
# │ max_pooling2d_3 (MaxPooling2D)    │ (None, 43, 43, 64)       │             0 │
# ├───────────────────────────────────┼──────────────────────────┼───────────────┤
# │ conv2d_8 (Conv2D)                 │ (None, 41, 41, 128)      │        73,856 │
# ├───────────────────────────────────┼──────────────────────────┼───────────────┤
# │ max_pooling2d_4 (MaxPooling2D)    │ (None, 20, 20, 128)      │             0 │
# ├───────────────────────────────────┼──────────────────────────┼───────────────┤
# │ conv2d_9 (Conv2D)                 │ (None, 18, 18, 256)      │       295,168 │
# ├───────────────────────────────────┼──────────────────────────┼───────────────┤
# │ max_pooling2d_5 (MaxPooling2D)    │ (None, 9, 9, 256)        │             0 │
# ├───────────────────────────────────┼──────────────────────────┼───────────────┤
# │ conv2d_10 (Conv2D)                │ (None, 7, 7, 512)        │     1,180,160 │
# ├───────────────────────────────────┼──────────────────────────┼───────────────┤
# │ global_average_pooling2d_2        │ (None, 512)              │             0 │
# │ (GlobalAveragePooling2D)          │                          │               │
# ├───────────────────────────────────┼──────────────────────────┼───────────────┤
# │ dense_2 (Dense)                   │ (None, 1)                │           513 │
# └───────────────────────────────────┴──────────────────────────┴───────────────┘
#  Total params: 1,569,089 (5.99 MB)
#  Trainable params: 1,569,089 (5.99 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
model.compile(
    loss="binary_crossentropy",
    optimizer="adam",
    metrics=["accuracy"],
)

# %% [markdown]
# #### Data preprocessing

# %%
from keras.utils import image_dataset_from_directory

batch_size = 64
image_size = (180, 180)
train_dataset = image_dataset_from_directory(
    new_base_dir / "train", image_size=image_size, batch_size=batch_size
)
validation_dataset = image_dataset_from_directory(
    new_base_dir / "validation", image_size=image_size, batch_size=batch_size
)
test_dataset = image_dataset_from_directory(
    new_base_dir / "test", image_size=image_size, batch_size=batch_size
)
# Out:
# Found 2000 files belonging to 2 classes.
# Found 1000 files belonging to 2 classes.
# Found 2000 files belonging to 2 classes.

# %% [markdown]
# ##### Understanding TensorFlow Dataset objects

# %%
import numpy as np
import tensorflow as tf

random_numbers = np.random.normal(size=(1000, 16))
dataset = tf.data.Dataset.from_tensor_slices(random_numbers)

# %%
for i, element in enumerate(dataset):
    print(element.shape)
    if i >= 2:
        break
# Out:
# (16,)
# (16,)
# (16,)

# %%
batched_dataset = dataset.batch(32)
for i, element in enumerate(batched_dataset):
    print(element.shape)
    if i >= 2:
        break
# Out:
# (32, 16)
# (32, 16)
# (32, 16)

# %%
reshaped_dataset = dataset.map(
    lambda x: tf.reshape(x, (4, 4)),
    num_parallel_calls=8)
for i, element in enumerate(reshaped_dataset):
    print(element.shape)
    if i >= 2:
        break
# Out:
# (4, 4)
# (4, 4)
# (4, 4)

# %% [markdown]
# ##### Fitting the model

# %%
for data_batch, labels_batch in train_dataset:
    print("data batch shape:", data_batch.shape)
    print("labels batch shape:", labels_batch.shape)
    break
# Out:
# data batch shape: (64, 180, 180, 3)
# labels batch shape: (64,)

# %%
callbacks = [
    keras.callbacks.ModelCheckpoint(
        filepath="convnet_from_scratch.keras",
        save_best_only=True,
        monitor="val_loss",
    )
]
history = model.fit(
    train_dataset,
    epochs=50,
    validation_data=validation_dataset,
    callbacks=callbacks,
)
# Out:
# /usr/local/lib/python3.13/dist-packages/keras/src/trainers/epoch_iterator.py:74: UserWarning: `shuffle=True` was passed, but will be ignored since the data `x` was provided as a tf.data.Dataset. The Dataset is expected to already be shuffled (via `.shuffle(buffer_size)`).
#   self.data_adapter = data_adapters.get_data_adapter(
# Epoch 1/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 24s 488ms/step - accuracy: 0.5050 - loss: 0.6987 - val_accuracy: 0.5000 - val_loss: 0.6929
# Epoch 2/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 121ms/step - accuracy: 0.5200 - loss: 0.6925 - val_accuracy: 0.5580 - val_loss: 0.6875
# Epoch 3/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 6s 175ms/step - accuracy: 0.5260 - loss: 0.6874 - val_accuracy: 0.5020 - val_loss: 0.6898
# Epoch 4/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 7s 208ms/step - accuracy: 0.5205 - loss: 0.6899 - val_accuracy: 0.6450 - val_loss: 0.6812
# Epoch 5/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 127ms/step - accuracy: 0.5500 - loss: 0.6823 - val_accuracy: 0.5390 - val_loss: 0.6879
# Epoch 6/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 130ms/step - accuracy: 0.5760 - loss: 0.6770 - val_accuracy: 0.5810 - val_loss: 0.6542
# Epoch 7/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 7s 206ms/step - accuracy: 0.5915 - loss: 0.6676 - val_accuracy: 0.5870 - val_loss: 0.6647
# Epoch 8/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 6s 196ms/step - accuracy: 0.6395 - loss: 0.6467 - val_accuracy: 0.5810 - val_loss: 0.6732
# Epoch 9/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 6s 175ms/step - accuracy: 0.6445 - loss: 0.6371 - val_accuracy: 0.6760 - val_loss: 0.6025
# Epoch 10/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 6s 189ms/step - accuracy: 0.6625 - loss: 0.6164 - val_accuracy: 0.6920 - val_loss: 0.6031
# Epoch 11/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 130ms/step - accuracy: 0.7045 - loss: 0.5813 - val_accuracy: 0.7260 - val_loss: 0.5649
# Epoch 12/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 6s 197ms/step - accuracy: 0.7070 - loss: 0.5665 - val_accuracy: 0.6140 - val_loss: 0.6295
# Epoch 13/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 129ms/step - accuracy: 0.6555 - loss: 0.6106 - val_accuracy: 0.7180 - val_loss: 0.5708
# Epoch 14/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 125ms/step - accuracy: 0.7305 - loss: 0.5411 - val_accuracy: 0.7420 - val_loss: 0.5374
# Epoch 15/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 6s 180ms/step - accuracy: 0.7450 - loss: 0.5224 - val_accuracy: 0.7500 - val_loss: 0.5249
# Epoch 16/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 132ms/step - accuracy: 0.7710 - loss: 0.4894 - val_accuracy: 0.6930 - val_loss: 0.5999
# Epoch 17/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 130ms/step - accuracy: 0.7590 - loss: 0.4977 - val_accuracy: 0.7440 - val_loss: 0.5273
# Epoch 18/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 6s 202ms/step - accuracy: 0.7550 - loss: 0.5033 - val_accuracy: 0.6690 - val_loss: 0.6245
# Epoch 19/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 7s 203ms/step - accuracy: 0.7740 - loss: 0.4890 - val_accuracy: 0.7690 - val_loss: 0.5097
# Epoch 20/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 156ms/step - accuracy: 0.7945 - loss: 0.4429 - val_accuracy: 0.7610 - val_loss: 0.5059
# Epoch 21/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 147ms/step - accuracy: 0.7940 - loss: 0.4470 - val_accuracy: 0.7360 - val_loss: 0.5609
# Epoch 22/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 132ms/step - accuracy: 0.7950 - loss: 0.4294 - val_accuracy: 0.7670 - val_loss: 0.5021
# Epoch 23/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 6s 172ms/step - accuracy: 0.8195 - loss: 0.4029 - val_accuracy: 0.7650 - val_loss: 0.5112
# Epoch 24/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 7s 199ms/step - accuracy: 0.8395 - loss: 0.3748 - val_accuracy: 0.7780 - val_loss: 0.4854
# Epoch 25/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 6s 200ms/step - accuracy: 0.8425 - loss: 0.3534 - val_accuracy: 0.7620 - val_loss: 0.5575
# Epoch 26/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 7s 203ms/step - accuracy: 0.8680 - loss: 0.3088 - val_accuracy: 0.7690 - val_loss: 0.5056
# Epoch 27/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 6s 200ms/step - accuracy: 0.8765 - loss: 0.3100 - val_accuracy: 0.7910 - val_loss: 0.5200
# Epoch 28/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 7s 212ms/step - accuracy: 0.8870 - loss: 0.2705 - val_accuracy: 0.7820 - val_loss: 0.5429
# Epoch 29/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 6s 199ms/step - accuracy: 0.8890 - loss: 0.2476 - val_accuracy: 0.7840 - val_loss: 0.5392
# Epoch 30/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 7s 218ms/step - accuracy: 0.9250 - loss: 0.2024 - val_accuracy: 0.7930 - val_loss: 0.5503
# Epoch 31/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 133ms/step - accuracy: 0.9350 - loss: 0.1631 - val_accuracy: 0.7840 - val_loss: 0.6367
# Epoch 32/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 131ms/step - accuracy: 0.9085 - loss: 0.2205 - val_accuracy: 0.8210 - val_loss: 0.5229
# Epoch 33/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 6s 201ms/step - accuracy: 0.9345 - loss: 0.1733 - val_accuracy: 0.7730 - val_loss: 0.6099
# Epoch 34/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 6s 199ms/step - accuracy: 0.9580 - loss: 0.1325 - val_accuracy: 0.8200 - val_loss: 0.5728
# Epoch 35/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 7s 213ms/step - accuracy: 0.9225 - loss: 0.1784 - val_accuracy: 0.7970 - val_loss: 0.5538
# Epoch 36/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 133ms/step - accuracy: 0.9370 - loss: 0.1593 - val_accuracy: 0.8210 - val_loss: 0.5392
# Epoch 37/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 132ms/step - accuracy: 0.9695 - loss: 0.0900 - val_accuracy: 0.8240 - val_loss: 0.5540
# Epoch 38/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 6s 201ms/step - accuracy: 0.9805 - loss: 0.0598 - val_accuracy: 0.7920 - val_loss: 0.8079
# Epoch 39/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 133ms/step - accuracy: 0.9765 - loss: 0.0682 - val_accuracy: 0.8220 - val_loss: 0.6821
# Epoch 40/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 7s 226ms/step - accuracy: 0.9650 - loss: 0.0928 - val_accuracy: 0.8270 - val_loss: 0.6521
# Epoch 41/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 140ms/step - accuracy: 0.9890 - loss: 0.0383 - val_accuracy: 0.8240 - val_loss: 0.6995
# Epoch 42/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 134ms/step - accuracy: 0.9960 - loss: 0.0201 - val_accuracy: 0.8100 - val_loss: 0.7967
# Epoch 43/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 7s 219ms/step - accuracy: 0.9915 - loss: 0.0274 - val_accuracy: 0.8220 - val_loss: 0.7594
# Epoch 44/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 128ms/step - accuracy: 0.9970 - loss: 0.0153 - val_accuracy: 0.8130 - val_loss: 0.9798
# Epoch 45/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 133ms/step - accuracy: 0.9960 - loss: 0.0191 - val_accuracy: 0.8260 - val_loss: 0.8837
# Epoch 46/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 159ms/step - accuracy: 0.9970 - loss: 0.0155 - val_accuracy: 0.8310 - val_loss: 0.8286
# Epoch 47/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 143ms/step - accuracy: 0.9855 - loss: 0.0360 - val_accuracy: 0.8210 - val_loss: 0.7339
# Epoch 48/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 6s 195ms/step - accuracy: 0.9880 - loss: 0.0330 - val_accuracy: 0.7790 - val_loss: 1.0937
# Epoch 49/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 6s 193ms/step - accuracy: 0.9960 - loss: 0.0158 - val_accuracy: 0.8330 - val_loss: 0.7928
# Epoch 50/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 133ms/step - accuracy: 0.9985 - loss: 0.0067 - val_accuracy: 0.8290 - val_loss: 0.8685

# %%
import matplotlib.pyplot as plt

accuracy = history.history["accuracy"]
val_accuracy = history.history["val_accuracy"]
loss = history.history["loss"]
val_loss = history.history["val_loss"]
epochs = range(1, len(accuracy) + 1)

plt.plot(epochs, accuracy, "r--", label="Training accuracy")
plt.plot(epochs, val_accuracy, "b", label="Validation accuracy")
plt.title("Training and validation accuracy")
plt.legend()
plt.figure()

plt.plot(epochs, loss, "r--", label="Training loss")
plt.plot(epochs, val_loss, "b", label="Validation loss")
plt.title("Training and validation loss")
plt.legend()
plt.show()

# %%
test_model = keras.models.load_model("convnet_from_scratch.keras")
test_loss, test_acc = test_model.evaluate(test_dataset)
print(f"Test accuracy: {test_acc:.3f}")
# Out:
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 8s 228ms/step - accuracy: 0.7805 - loss: 0.4787
# Test accuracy: 0.781

# %% [markdown]
# #### Using data augmentation

# %%
data_augmentation_layers = [
    layers.RandomFlip("horizontal"),
    layers.RandomRotation(0.1),
    layers.RandomZoom(0.2),
]

def data_augmentation(images, targets):
    for layer in data_augmentation_layers:
        images = layer(images)
    return images, targets

augmented_train_dataset = train_dataset.map(
    data_augmentation, num_parallel_calls=8
)
augmented_train_dataset = augmented_train_dataset.prefetch(tf.data.AUTOTUNE)

# %%
plt.figure(figsize=(10, 10))
for image_batch, _ in train_dataset.take(1):
    image = image_batch[0]
    for i in range(9):
        ax = plt.subplot(3, 3, i + 1)
        augmented_image, _ = data_augmentation(image, None)
        augmented_image = keras.ops.convert_to_numpy(augmented_image)
        plt.imshow(augmented_image.astype("uint8"))
        plt.axis("off")

# %%
inputs = keras.Input(shape=(180, 180, 3))
x = layers.Rescaling(1.0 / 255)(inputs)
x = layers.Conv2D(filters=32, kernel_size=3, activation="relu")(x)
x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Conv2D(filters=64, kernel_size=3, activation="relu")(x)
x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Conv2D(filters=128, kernel_size=3, activation="relu")(x)
x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Conv2D(filters=256, kernel_size=3, activation="relu")(x)
x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Conv2D(filters=512, kernel_size=3, activation="relu")(x)
x = layers.GlobalAveragePooling2D()(x)
x = layers.Dropout(0.25)(x)
outputs = layers.Dense(1, activation="sigmoid")(x)
model = keras.Model(inputs=inputs, outputs=outputs)

model.compile(
    loss="binary_crossentropy",
    optimizer="adam",
    metrics=["accuracy"],
)

# %%
callbacks = [
    keras.callbacks.ModelCheckpoint(
        filepath="convnet_from_scratch_with_augmentation.keras",
        save_best_only=True,
        monitor="val_loss",
    )
]
history = model.fit(
    augmented_train_dataset,
    epochs=100,
    validation_data=validation_dataset,
    callbacks=callbacks,
)
# Out:
# /usr/local/lib/python3.13/dist-packages/keras/src/trainers/epoch_iterator.py:74: UserWarning: `shuffle=True` was passed, but will be ignored since the data `x` was provided as a tf.data.Dataset. The Dataset is expected to already be shuffled (via `.shuffle(buffer_size)`).
#   self.data_adapter = data_adapters.get_data_adapter(
# Epoch 1/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 28s 548ms/step - accuracy: 0.5230 - loss: 0.6945 - val_accuracy: 0.6090 - val_loss: 0.6868
# Epoch 2/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 18s 553ms/step - accuracy: 0.5200 - loss: 0.6914 - val_accuracy: 0.5230 - val_loss: 0.6872
# Epoch 3/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 22s 675ms/step - accuracy: 0.5455 - loss: 0.6857 - val_accuracy: 0.5220 - val_loss: 0.6864
# Epoch 4/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 22s 599ms/step - accuracy: 0.5895 - loss: 0.6649 - val_accuracy: 0.6010 - val_loss: 0.6501
# Epoch 5/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 16s 486ms/step - accuracy: 0.5915 - loss: 0.6774 - val_accuracy: 0.6380 - val_loss: 0.6458
# Epoch 6/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 17s 482ms/step - accuracy: 0.6065 - loss: 0.6527 - val_accuracy: 0.6310 - val_loss: 0.6308
# Epoch 7/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 16s 474ms/step - accuracy: 0.6325 - loss: 0.6387 - val_accuracy: 0.6490 - val_loss: 0.6240
# Epoch 8/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 17s 485ms/step - accuracy: 0.6535 - loss: 0.6303 - val_accuracy: 0.6490 - val_loss: 0.6225
# Epoch 9/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 23s 679ms/step - accuracy: 0.6510 - loss: 0.6292 - val_accuracy: 0.6830 - val_loss: 0.5938
# Epoch 10/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 22s 641ms/step - accuracy: 0.6665 - loss: 0.6112 - val_accuracy: 0.6940 - val_loss: 0.5785
# Epoch 11/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 22s 690ms/step - accuracy: 0.6800 - loss: 0.5956 - val_accuracy: 0.6580 - val_loss: 0.6134
# Epoch 12/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 22s 648ms/step - accuracy: 0.6615 - loss: 0.6101 - val_accuracy: 0.6680 - val_loss: 0.5925
# Epoch 13/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 23s 660ms/step - accuracy: 0.6970 - loss: 0.5820 - val_accuracy: 0.7010 - val_loss: 0.5687
# Epoch 14/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 22s 631ms/step - accuracy: 0.7120 - loss: 0.5762 - val_accuracy: 0.7140 - val_loss: 0.5579
# Epoch 15/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 15s 426ms/step - accuracy: 0.6980 - loss: 0.5817 - val_accuracy: 0.7030 - val_loss: 0.5677
# Epoch 16/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 15s 460ms/step - accuracy: 0.6845 - loss: 0.6067 - val_accuracy: 0.7030 - val_loss: 0.5874
# Epoch 17/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 22s 688ms/step - accuracy: 0.6955 - loss: 0.5841 - val_accuracy: 0.6890 - val_loss: 0.5819
# Epoch 18/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 15s 432ms/step - accuracy: 0.7050 - loss: 0.5717 - val_accuracy: 0.7240 - val_loss: 0.5442
# Epoch 19/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 15s 442ms/step - accuracy: 0.7155 - loss: 0.5526 - val_accuracy: 0.7330 - val_loss: 0.5393
# Epoch 20/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 14s 412ms/step - accuracy: 0.7180 - loss: 0.5524 - val_accuracy: 0.7180 - val_loss: 0.5466
# Epoch 21/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 22s 659ms/step - accuracy: 0.7325 - loss: 0.5464 - val_accuracy: 0.7250 - val_loss: 0.5340
# Epoch 22/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 15s 426ms/step - accuracy: 0.7315 - loss: 0.5511 - val_accuracy: 0.7130 - val_loss: 0.5618
# Epoch 23/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 15s 439ms/step - accuracy: 0.7365 - loss: 0.5397 - val_accuracy: 0.7050 - val_loss: 0.5674
# Epoch 24/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 23s 714ms/step - accuracy: 0.7260 - loss: 0.5417 - val_accuracy: 0.7250 - val_loss: 0.5640
# Epoch 25/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 22s 667ms/step - accuracy: 0.7425 - loss: 0.5242 - val_accuracy: 0.7420 - val_loss: 0.5251
# Epoch 26/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 15s 440ms/step - accuracy: 0.7245 - loss: 0.5399 - val_accuracy: 0.7090 - val_loss: 0.5415
# Epoch 27/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 22s 675ms/step - accuracy: 0.7625 - loss: 0.5153 - val_accuracy: 0.7270 - val_loss: 0.5512
# Epoch 28/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 15s 449ms/step - accuracy: 0.7555 - loss: 0.5117 - val_accuracy: 0.7490 - val_loss: 0.5234
# Epoch 29/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 14s 423ms/step - accuracy: 0.7405 - loss: 0.5294 - val_accuracy: 0.6910 - val_loss: 0.5817
# Epoch 30/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 22s 675ms/step - accuracy: 0.7425 - loss: 0.5284 - val_accuracy: 0.7420 - val_loss: 0.5328
# Epoch 31/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 15s 441ms/step - accuracy: 0.7575 - loss: 0.5100 - val_accuracy: 0.7600 - val_loss: 0.5001
# Epoch 32/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 22s 663ms/step - accuracy: 0.7530 - loss: 0.5129 - val_accuracy: 0.7470 - val_loss: 0.5079
# Epoch 33/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 14s 424ms/step - accuracy: 0.7760 - loss: 0.4777 - val_accuracy: 0.7650 - val_loss: 0.4986
# Epoch 34/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 14s 401ms/step - accuracy: 0.7800 - loss: 0.4727 - val_accuracy: 0.7630 - val_loss: 0.5033
# Epoch 35/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 22s 662ms/step - accuracy: 0.7950 - loss: 0.4431 - val_accuracy: 0.7670 - val_loss: 0.5021
# Epoch 36/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 22s 648ms/step - accuracy: 0.8070 - loss: 0.4358 - val_accuracy: 0.7690 - val_loss: 0.5277
# Epoch 37/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 22s 658ms/step - accuracy: 0.7865 - loss: 0.4509 - val_accuracy: 0.7850 - val_loss: 0.4587
# Epoch 38/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 22s 667ms/step - accuracy: 0.8090 - loss: 0.4319 - val_accuracy: 0.8010 - val_loss: 0.4437
# Epoch 39/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 14s 428ms/step - accuracy: 0.8110 - loss: 0.4324 - val_accuracy: 0.7820 - val_loss: 0.4741
# Epoch 40/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 14s 431ms/step - accuracy: 0.7920 - loss: 0.4360 - val_accuracy: 0.7870 - val_loss: 0.4472
# Epoch 41/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 15s 439ms/step - accuracy: 0.8200 - loss: 0.3965 - val_accuracy: 0.7940 - val_loss: 0.4772
# Epoch 42/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 22s 662ms/step - accuracy: 0.8110 - loss: 0.4153 - val_accuracy: 0.7980 - val_loss: 0.4456
# Epoch 43/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 22s 665ms/step - accuracy: 0.8260 - loss: 0.4008 - val_accuracy: 0.7720 - val_loss: 0.4831
# Epoch 44/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 14s 415ms/step - accuracy: 0.8225 - loss: 0.3902 - val_accuracy: 0.7730 - val_loss: 0.5056
# Epoch 45/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 14s 433ms/step - accuracy: 0.8210 - loss: 0.3919 - val_accuracy: 0.8120 - val_loss: 0.4411
# Epoch 46/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 22s 665ms/step - accuracy: 0.8185 - loss: 0.3970 - val_accuracy: 0.8040 - val_loss: 0.4608
# Epoch 47/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 22s 648ms/step - accuracy: 0.8320 - loss: 0.3736 - val_accuracy: 0.8120 - val_loss: 0.4300
# Epoch 48/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 22s 668ms/step - accuracy: 0.8465 - loss: 0.3515 - val_accuracy: 0.8190 - val_loss: 0.4038
# Epoch 49/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 22s 639ms/step - accuracy: 0.8370 - loss: 0.3549 - val_accuracy: 0.7910 - val_loss: 0.4747
# Epoch 50/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 15s 433ms/step - accuracy: 0.8495 - loss: 0.3338 - val_accuracy: 0.8280 - val_loss: 0.4083
# Epoch 51/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 14s 376ms/step - accuracy: 0.8375 - loss: 0.3594 - val_accuracy: 0.8020 - val_loss: 0.4445
# Epoch 52/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 22s 671ms/step - accuracy: 0.8590 - loss: 0.3337 - val_accuracy: 0.7860 - val_loss: 0.5499
# Epoch 53/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 14s 410ms/step - accuracy: 0.8600 - loss: 0.3228 - val_accuracy: 0.8030 - val_loss: 0.4680
# Epoch 54/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 15s 426ms/step - accuracy: 0.8750 - loss: 0.3018 - val_accuracy: 0.8360 - val_loss: 0.4170
# Epoch 55/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 22s 660ms/step - accuracy: 0.8630 - loss: 0.3186 - val_accuracy: 0.8160 - val_loss: 0.4282
# Epoch 56/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 14s 415ms/step - accuracy: 0.8695 - loss: 0.3036 - val_accuracy: 0.8200 - val_loss: 0.3888
# Epoch 57/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 22s 656ms/step - accuracy: 0.8570 - loss: 0.3142 - val_accuracy: 0.8210 - val_loss: 0.3982
# Epoch 58/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 22s 648ms/step - accuracy: 0.8705 - loss: 0.3052 - val_accuracy: 0.8240 - val_loss: 0.4290
# Epoch 59/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 15s 458ms/step - accuracy: 0.8745 - loss: 0.2900 - val_accuracy: 0.8370 - val_loss: 0.3953
# Epoch 60/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 16s 456ms/step - accuracy: 0.8845 - loss: 0.2814 - val_accuracy: 0.7830 - val_loss: 0.5458
# Epoch 61/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 16s 464ms/step - accuracy: 0.8900 - loss: 0.2649 - val_accuracy: 0.8090 - val_loss: 0.4822
# Epoch 62/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 22s 657ms/step - accuracy: 0.8885 - loss: 0.2654 - val_accuracy: 0.7910 - val_loss: 0.5154
# Epoch 63/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 22s 657ms/step - accuracy: 0.8900 - loss: 0.2472 - val_accuracy: 0.8430 - val_loss: 0.4261
# Epoch 64/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 16s 453ms/step - accuracy: 0.8895 - loss: 0.2475 - val_accuracy: 0.8270 - val_loss: 0.4485
# Epoch 65/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 22s 653ms/step - accuracy: 0.8860 - loss: 0.2863 - val_accuracy: 0.8410 - val_loss: 0.3894
# Epoch 66/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 15s 435ms/step - accuracy: 0.8955 - loss: 0.2594 - val_accuracy: 0.8400 - val_loss: 0.4095
# Epoch 67/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 15s 433ms/step - accuracy: 0.9040 - loss: 0.2311 - val_accuracy: 0.8380 - val_loss: 0.4519
# Epoch 68/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 22s 668ms/step - accuracy: 0.9020 - loss: 0.2422 - val_accuracy: 0.8130 - val_loss: 0.5023
# Epoch 69/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 22s 665ms/step - accuracy: 0.8920 - loss: 0.2492 - val_accuracy: 0.8400 - val_loss: 0.4035
# Epoch 70/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 14s 421ms/step - accuracy: 0.8945 - loss: 0.2428 - val_accuracy: 0.8500 - val_loss: 0.4473
# Epoch 71/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 14s 417ms/step - accuracy: 0.9155 - loss: 0.2122 - val_accuracy: 0.8290 - val_loss: 0.3901
# Epoch 72/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 14s 416ms/step - accuracy: 0.9125 - loss: 0.2077 - val_accuracy: 0.8450 - val_loss: 0.4164
# Epoch 73/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 22s 661ms/step - accuracy: 0.9080 - loss: 0.2141 - val_accuracy: 0.8160 - val_loss: 0.5073
# Epoch 74/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 14s 427ms/step - accuracy: 0.9050 - loss: 0.2218 - val_accuracy: 0.8470 - val_loss: 0.3996
# Epoch 75/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 14s 394ms/step - accuracy: 0.9015 - loss: 0.2282 - val_accuracy: 0.8340 - val_loss: 0.4377
# Epoch 76/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 22s 644ms/step - accuracy: 0.9300 - loss: 0.1865 - val_accuracy: 0.8500 - val_loss: 0.4204
# Epoch 77/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 22s 675ms/step - accuracy: 0.9310 - loss: 0.1734 - val_accuracy: 0.8510 - val_loss: 0.4155
# Epoch 78/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 14s 429ms/step - accuracy: 0.9145 - loss: 0.2041 - val_accuracy: 0.8300 - val_loss: 0.4328
# Epoch 79/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 14s 438ms/step - accuracy: 0.9130 - loss: 0.2069 - val_accuracy: 0.8430 - val_loss: 0.4290
# Epoch 80/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 15s 431ms/step - accuracy: 0.8960 - loss: 0.2427 - val_accuracy: 0.8520 - val_loss: 0.3690
# Epoch 81/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 14s 430ms/step - accuracy: 0.9145 - loss: 0.2104 - val_accuracy: 0.8580 - val_loss: 0.3778
# Epoch 82/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 14s 414ms/step - accuracy: 0.9245 - loss: 0.1809 - val_accuracy: 0.8470 - val_loss: 0.4016
# Epoch 83/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 15s 415ms/step - accuracy: 0.9230 - loss: 0.1877 - val_accuracy: 0.8390 - val_loss: 0.4905
# Epoch 84/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 22s 682ms/step - accuracy: 0.9080 - loss: 0.2256 - val_accuracy: 0.8450 - val_loss: 0.4017
# Epoch 85/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 14s 393ms/step - accuracy: 0.9370 - loss: 0.1750 - val_accuracy: 0.8480 - val_loss: 0.4366
# Epoch 86/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 14s 404ms/step - accuracy: 0.9280 - loss: 0.1818 - val_accuracy: 0.8490 - val_loss: 0.4728
# Epoch 87/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 22s 658ms/step - accuracy: 0.9400 - loss: 0.1476 - val_accuracy: 0.8460 - val_loss: 0.4814
# Epoch 88/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 15s 433ms/step - accuracy: 0.9420 - loss: 0.1519 - val_accuracy: 0.8460 - val_loss: 0.5179
# Epoch 89/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 23s 712ms/step - accuracy: 0.9360 - loss: 0.1640 - val_accuracy: 0.8350 - val_loss: 0.4965
# Epoch 90/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 22s 648ms/step - accuracy: 0.9440 - loss: 0.1444 - val_accuracy: 0.8420 - val_loss: 0.4962
# Epoch 91/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 14s 384ms/step - accuracy: 0.9365 - loss: 0.1602 - val_accuracy: 0.8330 - val_loss: 0.5951
# Epoch 92/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 14s 416ms/step - accuracy: 0.9295 - loss: 0.1752 - val_accuracy: 0.8470 - val_loss: 0.4265
# Epoch 93/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 22s 631ms/step - accuracy: 0.9420 - loss: 0.1463 - val_accuracy: 0.8170 - val_loss: 0.5974
# Epoch 94/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 14s 426ms/step - accuracy: 0.9405 - loss: 0.1573 - val_accuracy: 0.8310 - val_loss: 0.5011
# Epoch 95/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 14s 392ms/step - accuracy: 0.9245 - loss: 0.1968 - val_accuracy: 0.8400 - val_loss: 0.4147
# Epoch 96/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 22s 662ms/step - accuracy: 0.9470 - loss: 0.1349 - val_accuracy: 0.8530 - val_loss: 0.4490
# Epoch 97/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 14s 398ms/step - accuracy: 0.9385 - loss: 0.1541 - val_accuracy: 0.8340 - val_loss: 0.4734
# Epoch 98/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 22s 660ms/step - accuracy: 0.9280 - loss: 0.1816 - val_accuracy: 0.8370 - val_loss: 0.4554
# Epoch 99/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 14s 432ms/step - accuracy: 0.9425 - loss: 0.1466 - val_accuracy: 0.8530 - val_loss: 0.4906
# Epoch 100/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 14s 409ms/step - accuracy: 0.9435 - loss: 0.1314 - val_accuracy: 0.8480 - val_loss: 0.5330

# %%
test_model = keras.models.load_model(
    "convnet_from_scratch_with_augmentation.keras"
)
test_loss, test_acc = test_model.evaluate(test_dataset)
print(f"Test accuracy: {test_acc:.3f}")
# Out:
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 71ms/step - accuracy: 0.8560 - loss: 0.3840
# Test accuracy: 0.856

# %% [markdown]
# ### Using a pretrained model

# %% [markdown]
# #### Feature extraction with a pretrained model

# %%
import keras_hub

conv_base = keras_hub.models.Backbone.from_preset("xception_41_imagenet")
# Out:
# Downloading to /root/.cache/kagglehub/models/keras/xception/keras/xception_41_imagenet/2/config.json...
# 100%|██████████| 1.79k/1.79k [00:00<00:00, 6.41MB/s]
# Downloading to /root/.cache/kagglehub/models/keras/xception/keras/xception_41_imagenet/2/model.weights.h5...
# 100%|██████████| 79.9M/79.9M [00:01<00:00, 44.8MB/s]

# %%
preprocessor = keras_hub.layers.ImageConverter.from_preset(
    "xception_41_imagenet",
    image_size=(180, 180),
)

# %% [markdown]
# ##### Fast feature extraction without data augmentation

# %%
def get_features_and_labels(dataset):
    all_features = []
    all_labels = []
    for images, labels in dataset:
        preprocessed_images = preprocessor(images)
        features = conv_base.predict(preprocessed_images, verbose=0)
        all_features.append(features)
        all_labels.append(labels)
    return np.concatenate(all_features), np.concatenate(all_labels)

train_features, train_labels = get_features_and_labels(train_dataset)
val_features, val_labels = get_features_and_labels(validation_dataset)
test_features, test_labels = get_features_and_labels(test_dataset)

# %%
train_features.shape
# Out:
# (2000, 6, 6, 2048)

# %%
inputs = keras.Input(shape=(6, 6, 2048))
x = layers.GlobalAveragePooling2D()(inputs)
x = layers.Dense(256, activation="relu")(x)
x = layers.Dropout(0.25)(x)
outputs = layers.Dense(1, activation="sigmoid")(x)
model = keras.Model(inputs, outputs)
model.compile(
    loss="binary_crossentropy",
    optimizer="adam",
    metrics=["accuracy"],
)

callbacks = [
    keras.callbacks.ModelCheckpoint(
        filepath="feature_extraction.keras",
        save_best_only=True,
        monitor="val_loss",
    )
]
history = model.fit(
    train_features,
    train_labels,
    epochs=10,
    validation_data=(val_features, val_labels),
    callbacks=callbacks,
)
# Out:
# Epoch 1/10
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - accuracy: 0.9585 - loss: 0.1010 - val_accuracy: 0.9820 - val_loss: 0.0488
# Epoch 2/10
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9865 - loss: 0.0369 - val_accuracy: 0.9860 - val_loss: 0.0479
# Epoch 3/10
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9945 - loss: 0.0162 - val_accuracy: 0.9860 - val_loss: 0.0502
# Epoch 4/10
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9990 - loss: 0.0059 - val_accuracy: 0.9870 - val_loss: 0.0529
# Epoch 5/10
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9995 - loss: 0.0032 - val_accuracy: 0.9870 - val_loss: 0.0511
# Epoch 6/10
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 1.0000 - loss: 0.0020 - val_accuracy: 0.9820 - val_loss: 0.0702
# Epoch 7/10
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9995 - loss: 0.0027 - val_accuracy: 0.9820 - val_loss: 0.0745
# Epoch 8/10
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9990 - loss: 0.0033 - val_accuracy: 0.9840 - val_loss: 0.0715
# Epoch 9/10
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 9.1597e-04 - val_accuracy: 0.9840 - val_loss: 0.0673
# Epoch 10/10
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 1.0000 - loss: 5.1644e-04 - val_accuracy: 0.9870 - val_loss: 0.0660

# %%
import matplotlib.pyplot as plt

acc = history.history["accuracy"]
val_acc = history.history["val_accuracy"]
loss = history.history["loss"]
val_loss = history.history["val_loss"]
epochs = range(1, len(acc) + 1)
plt.plot(epochs, acc, "r--", label="Training accuracy")
plt.plot(epochs, val_acc, "b", label="Validation accuracy")
plt.title("Training and validation accuracy")
plt.legend()
plt.figure()
plt.plot(epochs, loss, "r--", label="Training loss")
plt.plot(epochs, val_loss, "b", label="Validation loss")
plt.title("Training and validation loss")
plt.legend()
plt.show()

# %%
test_model = keras.models.load_model("feature_extraction.keras")
test_loss, test_acc = test_model.evaluate(test_features, test_labels)
print(f"Test accuracy: {test_acc:.3f}")
# Out:
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9835 - loss: 0.0498
# Test accuracy: 0.984

# %% [markdown]
# ##### Feature extraction together with data augmentation

# %%
import keras_hub

conv_base = keras_hub.models.Backbone.from_preset(
    "xception_41_imagenet",
    trainable=False,
)

# %%
conv_base.trainable = True
len(conv_base.trainable_weights)
# Out:
# 154

# %%
conv_base.trainable = False
len(conv_base.trainable_weights)
# Out:
# 0

# %%
inputs = keras.Input(shape=(180, 180, 3))
x = preprocessor(inputs)
x = conv_base(x)
x = layers.GlobalAveragePooling2D()(x)
x = layers.Dense(256)(x)
x = layers.Dropout(0.25)(x)
outputs = layers.Dense(1, activation="sigmoid")(x)
model = keras.Model(inputs, outputs)
model.compile(
    loss="binary_crossentropy",
    optimizer="adam",
    metrics=["accuracy"],
)

# %%
callbacks = [
    keras.callbacks.ModelCheckpoint(
        filepath="feature_extraction_with_data_augmentation.keras",
        save_best_only=True,
        monitor="val_loss",
    )
]
history = model.fit(
    augmented_train_dataset,
    epochs=30,
    validation_data=validation_dataset,
    callbacks=callbacks,
)
# Out:
# /usr/local/lib/python3.13/dist-packages/keras/src/trainers/epoch_iterator.py:74: UserWarning: `shuffle=True` was passed, but will be ignored since the data `x` was provided as a tf.data.Dataset. The Dataset is expected to already be shuffled (via `.shuffle(buffer_size)`).
#   self.data_adapter = data_adapters.get_data_adapter(
# Epoch 1/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 64s 1s/step - accuracy: 0.9305 - loss: 0.1791 - val_accuracy: 0.9810 - val_loss: 0.0699
# Epoch 2/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 25s 750ms/step - accuracy: 0.9680 - loss: 0.0882 - val_accuracy: 0.9840 - val_loss: 0.0532
# Epoch 3/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 24s 734ms/step - accuracy: 0.9715 - loss: 0.0702 - val_accuracy: 0.9820 - val_loss: 0.0590
# Epoch 4/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 24s 739ms/step - accuracy: 0.9695 - loss: 0.0862 - val_accuracy: 0.9770 - val_loss: 0.0815
# Epoch 5/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 17s 532ms/step - accuracy: 0.9775 - loss: 0.0649 - val_accuracy: 0.9800 - val_loss: 0.0545
# Epoch 6/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 24s 743ms/step - accuracy: 0.9785 - loss: 0.0729 - val_accuracy: 0.9820 - val_loss: 0.0627
# Epoch 7/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 24s 742ms/step - accuracy: 0.9820 - loss: 0.0568 - val_accuracy: 0.9820 - val_loss: 0.0575
# Epoch 8/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 24s 710ms/step - accuracy: 0.9845 - loss: 0.0453 - val_accuracy: 0.9770 - val_loss: 0.0633
# Epoch 9/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 24s 732ms/step - accuracy: 0.9780 - loss: 0.0630 - val_accuracy: 0.9830 - val_loss: 0.0535
# Epoch 10/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 24s 719ms/step - accuracy: 0.9785 - loss: 0.0584 - val_accuracy: 0.9810 - val_loss: 0.0631
# Epoch 11/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 17s 517ms/step - accuracy: 0.9730 - loss: 0.0857 - val_accuracy: 0.9820 - val_loss: 0.0592
# Epoch 12/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 24s 742ms/step - accuracy: 0.9805 - loss: 0.0522 - val_accuracy: 0.9820 - val_loss: 0.0583
# Epoch 13/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 24s 725ms/step - accuracy: 0.9835 - loss: 0.0411 - val_accuracy: 0.9760 - val_loss: 0.0695
# Epoch 14/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 16s 478ms/step - accuracy: 0.9795 - loss: 0.0556 - val_accuracy: 0.9750 - val_loss: 0.0714
# Epoch 15/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 24s 720ms/step - accuracy: 0.9855 - loss: 0.0390 - val_accuracy: 0.9770 - val_loss: 0.0601
# Epoch 16/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 17s 480ms/step - accuracy: 0.9820 - loss: 0.0442 - val_accuracy: 0.9830 - val_loss: 0.0556
# Epoch 17/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 16s 458ms/step - accuracy: 0.9835 - loss: 0.0396 - val_accuracy: 0.9800 - val_loss: 0.0583
# Epoch 18/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 16s 481ms/step - accuracy: 0.9840 - loss: 0.0392 - val_accuracy: 0.9790 - val_loss: 0.0651
# Epoch 19/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 17s 507ms/step - accuracy: 0.9840 - loss: 0.0402 - val_accuracy: 0.9790 - val_loss: 0.0633
# Epoch 20/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 24s 758ms/step - accuracy: 0.9875 - loss: 0.0359 - val_accuracy: 0.9830 - val_loss: 0.0516
# Epoch 21/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 25s 765ms/step - accuracy: 0.9865 - loss: 0.0321 - val_accuracy: 0.9800 - val_loss: 0.0502
# Epoch 22/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 24s 727ms/step - accuracy: 0.9830 - loss: 0.0407 - val_accuracy: 0.9810 - val_loss: 0.0574
# Epoch 23/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 17s 517ms/step - accuracy: 0.9865 - loss: 0.0391 - val_accuracy: 0.9780 - val_loss: 0.0634
# Epoch 24/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 24s 725ms/step - accuracy: 0.9800 - loss: 0.0516 - val_accuracy: 0.9840 - val_loss: 0.0551
# Epoch 25/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 17s 512ms/step - accuracy: 0.9840 - loss: 0.0501 - val_accuracy: 0.9790 - val_loss: 0.0671
# Epoch 26/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 24s 712ms/step - accuracy: 0.9775 - loss: 0.0699 - val_accuracy: 0.9850 - val_loss: 0.0528
# Epoch 27/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 17s 498ms/step - accuracy: 0.9805 - loss: 0.0534 - val_accuracy: 0.9820 - val_loss: 0.0622
# Epoch 28/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 24s 727ms/step - accuracy: 0.9800 - loss: 0.0557 - val_accuracy: 0.9830 - val_loss: 0.0600
# Epoch 29/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 24s 725ms/step - accuracy: 0.9900 - loss: 0.0337 - val_accuracy: 0.9810 - val_loss: 0.0675
# Epoch 30/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 24s 742ms/step - accuracy: 0.9775 - loss: 0.0645 - val_accuracy: 0.9810 - val_loss: 0.0677

# %%
test_model = keras.models.load_model(
    "feature_extraction_with_data_augmentation.keras"
)
test_loss, test_acc = test_model.evaluate(test_dataset)
print(f"Test accuracy: {test_acc:.3f}")
# Out:
# /usr/local/lib/python3.13/dist-packages/keras/src/saving/saving_lib.py:869: UserWarning: Skipping variable loading for optimizer 'adam_4', because it has 318 variables whereas the saved optimizer has 10 variables.
#   saveable.load_own_variables(store)
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 14s 314ms/step - accuracy: 0.9845 - loss: 0.0549
# Test accuracy: 0.985

# %% [markdown]
# #### Fine-tuning a pretrained model

# %%
model.compile(
    loss="binary_crossentropy",
    optimizer=keras.optimizers.Adam(learning_rate=1e-5),
    metrics=["accuracy"],
)

callbacks = [
    keras.callbacks.ModelCheckpoint(
        filepath="fine_tuning.keras",
        save_best_only=True,
        monitor="val_loss",
    )
]
history = model.fit(
    augmented_train_dataset,
    epochs=30,
    validation_data=validation_dataset,
    callbacks=callbacks,
)
# Out:
# Epoch 1/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 33s 751ms/step - accuracy: 0.9870 - loss: 0.0326 - val_accuracy: 0.9820 - val_loss: 0.0596
# Epoch 2/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 18s 527ms/step - accuracy: 0.9850 - loss: 0.0326 - val_accuracy: 0.9830 - val_loss: 0.0555
# Epoch 3/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 16s 481ms/step - accuracy: 0.9875 - loss: 0.0349 - val_accuracy: 0.9830 - val_loss: 0.0555
# Epoch 4/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 16s 471ms/step - accuracy: 0.9920 - loss: 0.0232 - val_accuracy: 0.9830 - val_loss: 0.0555
# Epoch 5/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 18s 518ms/step - accuracy: 0.9880 - loss: 0.0287 - val_accuracy: 0.9830 - val_loss: 0.0548
# Epoch 6/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 17s 498ms/step - accuracy: 0.9895 - loss: 0.0306 - val_accuracy: 0.9840 - val_loss: 0.0539
# Epoch 7/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 18s 529ms/step - accuracy: 0.9925 - loss: 0.0249 - val_accuracy: 0.9840 - val_loss: 0.0533
# Epoch 8/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 24s 723ms/step - accuracy: 0.9925 - loss: 0.0231 - val_accuracy: 0.9850 - val_loss: 0.0536
# Epoch 9/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 17s 509ms/step - accuracy: 0.9920 - loss: 0.0225 - val_accuracy: 0.9850 - val_loss: 0.0537
# Epoch 10/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 16s 465ms/step - accuracy: 0.9895 - loss: 0.0310 - val_accuracy: 0.9840 - val_loss: 0.0534
# Epoch 11/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 25s 743ms/step - accuracy: 0.9900 - loss: 0.0262 - val_accuracy: 0.9840 - val_loss: 0.0530
# Epoch 12/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 25s 741ms/step - accuracy: 0.9915 - loss: 0.0224 - val_accuracy: 0.9840 - val_loss: 0.0526
# Epoch 13/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 18s 477ms/step - accuracy: 0.9925 - loss: 0.0215 - val_accuracy: 0.9840 - val_loss: 0.0526
# Epoch 14/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 16s 470ms/step - accuracy: 0.9915 - loss: 0.0226 - val_accuracy: 0.9840 - val_loss: 0.0525
# Epoch 15/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 24s 755ms/step - accuracy: 0.9855 - loss: 0.0352 - val_accuracy: 0.9850 - val_loss: 0.0524
# Epoch 16/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 16s 458ms/step - accuracy: 0.9905 - loss: 0.0241 - val_accuracy: 0.9840 - val_loss: 0.0527
# Epoch 17/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 24s 746ms/step - accuracy: 0.9865 - loss: 0.0307 - val_accuracy: 0.9830 - val_loss: 0.0540
# Epoch 18/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 24s 699ms/step - accuracy: 0.9925 - loss: 0.0231 - val_accuracy: 0.9830 - val_loss: 0.0535
# Epoch 19/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 24s 720ms/step - accuracy: 0.9880 - loss: 0.0381 - val_accuracy: 0.9840 - val_loss: 0.0527
# Epoch 20/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 25s 765ms/step - accuracy: 0.9950 - loss: 0.0186 - val_accuracy: 0.9850 - val_loss: 0.0518
# Epoch 21/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 25s 760ms/step - accuracy: 0.9920 - loss: 0.0234 - val_accuracy: 0.9850 - val_loss: 0.0517
# Epoch 22/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 16s 468ms/step - accuracy: 0.9915 - loss: 0.0226 - val_accuracy: 0.9850 - val_loss: 0.0522
# Epoch 23/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 16s 459ms/step - accuracy: 0.9920 - loss: 0.0243 - val_accuracy: 0.9850 - val_loss: 0.0523
# Epoch 24/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 17s 520ms/step - accuracy: 0.9920 - loss: 0.0212 - val_accuracy: 0.9850 - val_loss: 0.0526
# Epoch 25/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 24s 742ms/step - accuracy: 0.9930 - loss: 0.0201 - val_accuracy: 0.9850 - val_loss: 0.0522
# Epoch 26/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 24s 721ms/step - accuracy: 0.9890 - loss: 0.0271 - val_accuracy: 0.9850 - val_loss: 0.0523
# Epoch 27/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 17s 481ms/step - accuracy: 0.9900 - loss: 0.0290 - val_accuracy: 0.9850 - val_loss: 0.0515
# Epoch 28/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 24s 735ms/step - accuracy: 0.9910 - loss: 0.0291 - val_accuracy: 0.9850 - val_loss: 0.0522
# Epoch 29/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 24s 677ms/step - accuracy: 0.9915 - loss: 0.0238 - val_accuracy: 0.9850 - val_loss: 0.0522
# Epoch 30/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 24s 748ms/step - accuracy: 0.9895 - loss: 0.0232 - val_accuracy: 0.9850 - val_loss: 0.0517

# %%
model = keras.models.load_model("fine_tuning.keras")
test_loss, test_acc = model.evaluate(test_dataset)
print(f"Test accuracy: {test_acc:.3f}")
# Out:
# /usr/local/lib/python3.13/dist-packages/keras/src/saving/saving_lib.py:869: UserWarning: Skipping variable loading for optimizer 'adam_5', because it has 318 variables whereas the saved optimizer has 10 variables.
#   saveable.load_own_variables(store)
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 13s 290ms/step - accuracy: 0.9860 - loss: 0.0485
# Test accuracy: 0.986
